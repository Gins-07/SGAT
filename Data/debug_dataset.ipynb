# %%
import sys
sys.path.append('../')

from aligned_dataset_xr import XRDataset
from Config.gan_xr_options import gan_xr_v1

# %%
config = gan_xr_v1()

# %%
xrdataset = XRDataset()
xrdataset.initialize(config)

# %%
import sys
sys.path.append('../')

# from aligned_dataset_xrseq import XRDataset_Seq
from aligned_dataset_xre import XRDataset

from Config.gan_xre_options import gan_xre_v4

config = gan_xre_v4()

xrdataset = XRDataset()
xrdataset.initialize(config)

# %%
import pylab as plt
plt.figure(figsize=[20,10])
t = xrdataset.__getitem__(10)
plt.subplot(1,2,1)
plt.imshow(t['A'].numpy().transpose(1,2,0))
plt.subplot(1,2,2)
plt.imshow(t['B'].float().numpy()[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
