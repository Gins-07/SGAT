# %%
import sys
sys.path.append('../')

# from aligned_dataset_xrseq import XRDataset_Seq
from aligned_dataset_xre import XRDataset


from Config.gan_xre_options import gan_xre_v1 

config = gan_xre_v1()

xrdataset = XRDataset()
xrdataset.initialize(config)

# %%
t = xrdataset.__getitem__(0)
t['A'].shape,t['B'].shape,t['B'].unsqueeze(0).shape
# Out:
# (torch.Size([1, 256, 256]),
#  torch.Size([1, 256, 256]),
#  torch.Size([1, 1, 256, 256]))

# %%
import pylab as plt
plt.figure(figsize=[20,10])
t = xrdataset.__getitem__(0)
plt.subplot(1,2,1)
plt.imshow(t['A'].numpy()[0])
plt.subplot(1,2,2)
plt.imshow(t['B'].numpy()[0])

# %%
t['B'].numpy()[0].dtype
# Out:
# dtype('float32')

# %%
import sys
sys.path.append('../')

# from aligned_dataset_xrseq import XRDataset_Seq
from aligned_dataset_xr import XRDataset


from Config.gan_xr_options import gan_xr_v1 

config = gan_xr_v1()

xrdataset2 = XRDataset()
xrdataset2.initialize(config)

# %%
t2 = xrdataset2.__getitem__(0)
t2['A'].shape,t2['B'].shape
# Out:
# (torch.Size([1, 256, 256]), torch.Size([1, 256, 256]))
